# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../classes')
sys.path.append('../modules')
from BuildSpecimen import build_specimens_output
import numpy as np
import sympy as sym
from Material import Material
# from abdCalcs import ABDs
from SandwichPanel import TestSpecimen
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from MomInertia import moments_of_inertia
import os
import pandas as pd

# %% [markdown]
# #### Creating Test Specimens from the Excel Sheet

# %%
#Reading in Coupond Data Sheet
cwd = os.getcwd()
pardir = os.path.dirname(os.path.dirname(cwd))
specimens_fp = os.path.join(pardir,'CouponData','CouponIDDataSheetReformat.xlsx')
build_specimens_output(specimens_fp)
# Out:
# nan
# nan
#     ID Stringer Material Foam Material           Top Lamina Bottom Lamina  \
# 0  NA1             Balsa      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
# 1  NA2             Balsa      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
# 2  101             Balsa      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
# 3  102             Balsa      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
# 4  103             Balsa      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
# 5  104             Balsa      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
# 6  201         Birchwood      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
# 7  202         Birchwood      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
# 8  203         Birchwood      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
# 9  204         Birchwood      EPS_Foam  Eglass4oz,Eglass6oz     Eglass4oz
#
#    Stringer Width (in)  Lamina Thickness  Foam Width  Foam Height  \
# 0                0.125          0.009843         6.0          2.5
# 1                0.125          0.009843         6.0          2.5
# 2                  NaN               NaN         NaN          NaN
# 3                  NaN               NaN         NaN          NaN
# 4                  NaN               NaN         NaN          NaN
# 5                  NaN               NaN         NaN          NaN
# 6                  NaN               NaN         NaN          NaN
# 7                  NaN               NaN         NaN          NaN
# 8                  NaN               NaN         NaN          NaN
# 9                  NaN               NaN         NaN          NaN
#
#    weight (lb)  Failure Load (lb)   Lw  Half Distance Between Supports  \
# 0          NaN              400.0  2.0                            11.0
# 1          NaN              300.0  2.0                            11.0
# 2     0.300931                NaN  NaN                             NaN
# 3     0.303356                NaN  NaN                             NaN
# 4     0.292333                NaN  NaN                             NaN
# 5     0.311072                NaN  NaN                             NaN
# 6     0.279766                NaN  NaN                             NaN
# 7     0.273814                NaN  NaN                             NaN
# 8     0.278884                NaN  NaN                             NaN
# 9     0.282191                NaN  NaN                             NaN
#
#                                        TestSpecimens
# 0  <SandwichPanel.TestSpecimen object at 0x000001...
# 1  <SandwichPanel.TestSpecimen object at 0x000001...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# #### TODO
#
# 1. Calculate the axial stress that is in the laminate and add this as an instance variable
#
# 2. Add new columns for specimen_results. things like max load, etc
#
# 3. Make new method to incorporate the force vs. displacement plots into the TestSpecimen class and do linear regression on it to get polynomial coefficients that can be used later with ml and stuff.
#
# 4. Create a separate dataframe with a shit ton of dimensions and try to figure out the best thing that optimizes weight and stuff.
